# %% [markdown]
# # High cost drugs dataset
#
# ## Short data report
#
# This short report describes how high cost drugs data can be analysed in OpenSAFELY. The report discusses the strengths and weaknesses of the data available to be queried as part of an OpenSAFELY study definition and gives a brief overview of other variables in the high cost drugs data that are not yet available to query via study definitions.
#
# This is a living document that will be updated to reflect changes to the OpenSAFELY platform and the patient records within.

# %% [markdown]
# ## Introduction
#
# The high cost drugs dataset is a patient level dataset that provides information on the use of drugs that are tariff-excluded. These are medicines that are not reimbursed directly through the national tariff and comissioned either by NHS England & Improvement (NHSEI) specialised commissioning or Clinic Commissioning Groups (CCGs).
#
# The main purpose of the collection of data on the use of high cost drugs is for payments from NHSEI specialised commissioning or CCGs to hospitals once a drug has been prescribed to a patient. Hospitals fill out a submission for each patient and each high cost drug and submit this to either a CCG or NHSEI specialised commissioning, based on which organisation is the commissioner, to recieve payment.
#
# As a secondary use these individual submissions can then be collected together to provide information on the total number of patients treated with high cost drugs, the volume of high cost drugs used and the cost of these medicines to commissioners. The dataset also provides information on clinical indications, the reason a patient was treated with the high cost drug, and the month the patient was treated.

# %% [markdown]
# ## Analysing high cost drugs data in OpenSAFELY
#
# High cost drugs data is available for analysis via the OpenSAFELY platform to answer COVID-19 related research questions. The high cost drugs data can be analysed via OpenSAFELY study definitions and linked to information from patient GP records, COVID-19 related datasets (tests and results), hospital admissions and episodes data and data on patient outcomes. This will allow new insight in to the possible interactions between the medication a patient takes and COVID outcomes.
#
# Currently, three variables from the high cost drugs dataset can be queried in an OpenSAFELY study:
# * FinancialMonth
# * FinancialYear
# * DrugName
#
# These variables are the ones most relevant to current research questions and add new information not available in other OpenSAFELY datasets. These are also some of the most complete variables in the dataset. Other variables included in the high cost drugs dataset are described in Table one and two below.
#
# The steps to analyse data via OpenSAFELY study definitions are set out in this [guidance](https://docs.opensafely.org/en/latest/). There are some specific things to note when including the high cost drugs dataset in any analysis:
# * You will need to create bespoke codelists to cover the medications of interest - as the drug name variable does not follow an existing naming convention these codelists are created by reviewing the list of all unique values in the drug name variable and selecting the ones that are relevant to your research question.
#     * A list of the existing high cost drugs codelists on OpenSAFELY codelists can be found [here](https://codelists.opensafely.org/?q=High+cost+drugs). Check this to see if a codelist already exists for your medications of interest.
#     * If a codelist does not already exist then you will need to create one. These codelists will need to be based on the unique values of the drug name variable. A list of all the unique values for the drug name variable can be found here (add link!).
#     * Once you have created the codelist/lists for the medicines of interest these need to be reviewed and uploaded to [OpenSAFELY codelists](https://codelists.opensafely.org/codelist/opensafely/add/), following the process set out in [this guidance](https://docs.opensafely.org/en/latest/codelist-creation/).(High cost drugs approach is slightly different - does the guidance need to be updated to reflect this?)
#
# * When you are ready to run your study definition and analysis via the [Job Runner](https://jobs.opensafely.org/) you will need to run on the full set of data as the high cost drugs dataset is not yet included in the slice of data (which can be used to test your study runs as expected).

# %% [markdown]
# ## Background information - Creation of the national high cost drugs dataset
#
# The high cost drug payment request submissions are routinely collected together to produce datasets at an individual CCG and NHSEI specialised commissioning level. However, despite clear use cases for national policy and clinical teams, academics and other stakeholders, this data had never been collected together to provide a national overview of the use of high cost drugs in England prior to the work of the North of England Commissioing Support Unit (NECS) and the DataLab in spring/summer 2020.
#
# *To add information on how national data collection was proposed/approved*
#
# To create the first national high cost drugs dataset the NECS collected submissions from all commissioners in England - this covers 135 CCGs and NHSEI specialised commissioning. The scope of the original dataset was all high cost drugs sumbissions from FY 2018/19 and FY 2019/20.
#
# The NECS faced a number of challenges in collecting and collating the submissions from this range of providers, particularly around data uniformity and validation. The impact of these challenges are discussed for each variable where relevant.
#
# **Caveats**
# * The NECS are unable to say with any certainty that the data received is a complete data set for each Provider and Commissioner for FY 2018/19 and FY 2019/20.
# * The drug names and some other text inputs are non-standardised, this is a feature of the data collection process. This means that further data cleaning and standardisation is required each time the high cost drugs dataset is used for new analysis.
# * The NECS are unable to comment on the level of data validation that had been undertaken by commissioners before the data was submitted to them for collation.
#
# Further information on the NECS data collation and cleaning processes can be found in [this document.](https://docs.google.com/document/d/1JbUPp962KRNGsIC1wThexdMUrV0XOb-D/edit#heading=h.gjdgxs) (This is currently on the DataLab google drive so needs to be moved to a public place if going to be referenced here.)

# %% [markdown]
# ## Variable overview
#
# The national high cost drugs dataset is a patient level dataset and includes variables on patient characteristics, clinical indications and medicine prescribed.
#
# The data collection of inidivudal submissions is called the Drugs Patient Level Contract Monitoring Data Set and the national specification for submissions is published on the [NHS Data Model and Dictionary website](https://datadictionary.nhs.uk/data_sets/supporting_data_sets/drugs_patient_level_contract_monitoring_data_set.html). A full list of the variables collected via submissions and specification for each variable can be found via this link.
#
# The NECS collated together the submissions to all commissioners in England to create a national dataset. The version of this dataset shared with OpenSAFELY includes a subset of the variables from the national specification and some derived variables. The dataset shared with OpenSAFELY only includes patients that are or were registered at a GP practice that uses the TPP EHRC systems. This data collection is therefore a sample of the full national high cost drugs dataset that the NECS produced.
#
# A description of each of the variables in the OpenSAFELY high cost drugs dataset is provided in **Table one** below and a brief overview of the type of data collected is in **Table two**.

# %% [markdown]
# ### Table one: Variables included in the OpenSAFELY high cost drugs dataset
#
# |Variable Name | Variable Type | Specification details | Variable description |
# :--------------|:---------------|:---------------------|:-------------------|
# |Patient_Id | n10 | Mandatory where relevant | Psdonomised patient id, used to match dataset to other datasets within OpenSAFELY-TPP.|
# | FinancialMonth|max an2| Mandatory  | **Able to query in OpenSAFELY study definition** <br> Financial month the prescribed item was administered to patient.<br> 1 = April <br> ... <br> 12 = March|
# |FinancialYear | an6 | Mandatory| **Able to query in OpenSAFELY study definition** <br>  Financial year the prescribed item was administered to patient.  <br> FY 2018/19 = 201819|
# |PersonAge | n | Derived | Age of patient when prescribed item was administered to patient. <br> Some submissions included age at intervention. <br> Where missing this variable was derived using clinical intervention date and date of birth.|
# |PersonGender | an1 |Mandatory where relevant | Gender as stated by the patient. <br> 1 = Male <br> 2 = Female <br> 9 = Indeterminate (unable to be classified as either male or female)|
# |ActivityTreatmentFunctionCode | an3 |Mandatory where relevant <br> Full list of codes [here](https://datadictionary.nhs.uk/data_elements/activity_treatment_function_code.html) | Code to describe the clinical area that prescribing is taking place in, based on main speciality.|
# |TherapeuticIndicationCode | min an6 <br> max an20| Mandatory where relevant <br> SNOMED CT Code| Code used to identify the reason for administering drug to the patient.|
# |HighCostTariffExcludedDrugCode|min an6 <br> max an20 |Optional <br> SNOMED CT dm+d | dm+d description of medicine administred to patient. <br> Only populated when provider has dm+d enabled system.|
# |DrugName|max an255 | Mandatory where relevant <br> Free text | **Able to query in OpenSAFELY study definition** <br> The name of the prescribed item. <br> Should be the SNOMED CT name. <br> For drugs not listed in dm+d, this must be the valid name in UPPER CASE.|
# |Route of Administration|min an6 <br> max an20 |Mandatory where relevant <br> SNOMED CT dm+d|To be populated by providers with an e-prescribing system.|
# |DrugStrength|max an100 |Mandatory where relevant | The amount of ingredient substance in the prescribed item.|
# |DrugVolume|max an100| Mandatory where relevant| The volume of the drug administered to a patient when given in liquid form.|
# |DrugPackSize| max an100| Optional| The amount of product in a pack or container.|
# |DrugQuanitityOrWeightProportion*|max n4.max n4|Mandatory where relevant | The quantity prescribed in terms of either the packsize or number of doses. <br> * To note, the variable name is misspelled.|
# |UnitOfMeasurement | |Mandatory where relevant <br> SNOMED CT dm+d | Describes what the DrugQuantityOrWeightProportion variable is measuring.|
# |DispensingRoute|an1| Mandatory where releavant.|Describes where the prescription item was dispensed to the patient. <br> 1 = Inpatient (via Internal Pharmacy) <br> 2 = Outpatient (via Internal Pharmacy) <br> 3 = Outsourced Pharmacy <br> 4 = Homecare Delivery <br> 5 = Community Pharmacy (FP10) <br> 6 = Other (not listed)|
# |HomeDeliveryCharge|max n18.max n8 | Mandatory| The amount charged for delivery of item to patient's home. |
# |TotalCost| max n18.max n8| Mandatory| The total cost of the activity that includes any agreed adjustments.|
# |DerivedSNOMEDFromName|max an255 | Derived by NECS | NECS derived variable. <br> dm+d code <br> Over 90% NULL (see table 2)|
# |DerivedVTM|max an255| Derived by NECS | NECS derived variable <br> dm+d code <br> Around one third NULL (see table 2)|
# |DerivedVTMName| max an255| Dervied by NECS |NECS derived variable <br> VTM name derived from VTM dm+d code. <br> Around one third NULL (see table 2)|

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# ### Table two: Summary of variables - NULL values, type of data and unique values

# %%
# runnning code to import libraries
import pandas as pd
import numpy as np
import os as os
from matplotlib import pyplot as plt

# %%
# bringing in variable summary table

# steps to get the correct filepath for the csv file and read in variable summary
os.getcwd()
parentDirectory = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
path = "/released-output/"
filename = parentDirectory + path + "Variable_Summary.csv"

variable_summary = pd.read_csv(filename, index_col = False)
variable_summary_1 = variable_summary[["VariableName", "FinancialYear", "TotalRecords", "PropNULL", "PropNumeric_OfNotNULL", "TotalUniqueValues"]]
variable_summary_2 = variable_summary_1.rename(columns={'VariableName': 'Variable Name', 
                                                        'FinancialYear': 'Financial Year',
                                                       'TotalRecords': 'Total Records',
                                                       'PropNULL': '% NULL',
                                                       'PropNumeric_OfNotNULL': '% Numeric (and not NULL)',
                                                       'TotalUniqueValues': 'Number of Unique Values'})
variable_summary_3 = variable_summary_2.sort_values(by=['Variable Name', 'Financial Year']).reset_index(drop = True)
variable_summary_4 = variable_summary_3.style.format({'% NULL': "{:.1%}", '% Numeric (and not NULL)': '{:.1%}'}).hide_index()
variable_summary_4
# Out:
# <style  type="text/css" >
# </style><table id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9f" ><thead>    <tr>        <th class="col_heading level0 col0" >Variable Name</th>        <th class="col_heading level0 col1" >Financial Year</th>        <th class="col_heading level0 col2" >Total Records</th>        <th class="col_heading level0 col3" >% NULL</th>        <th class="col_heading level0 col4" >% Numeric (and not NULL)</th>        <th class="col_heading level0 col5" >Number of Unique Values</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow0_col0" class="data row0 col0" >ActivityTreatmentFunctionCode</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow0_col1" class="data row0 col1" >201819</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow0_col2" class="data row0 col2" >2799394</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow0_col3" class="data row0 col3" >9.2%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow0_col4" class="data row0 col4" >100.0%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow0_col5" class="data row0 col5" >144</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow1_col0" class="data row1 col0" >ActivityTreatmentFunctionCode</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow1_col1" class="data row1 col1" >201920</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow1_col2" class="data row1 col2" >3984198</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow1_col3" class="data row1 col3" >6.0%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow1_col4" class="data row1 col4" >100.0%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow1_col5" class="data row1 col5" >143</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow2_col0" class="data row2 col0" >DerivedSNOMED</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow2_col1" class="data row2 col1" >201819</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow2_col2" class="data row2 col2" >2799394</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow2_col3" class="data row2 col3" >92.3%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow2_col4" class="data row2 col4" >100.0%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow2_col5" class="data row2 col5" >205</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow3_col0" class="data row3 col0" >DerivedSNOMED</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow3_col1" class="data row3 col1" >201920</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow3_col2" class="data row3 col2" >3984198</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow3_col3" class="data row3 col3" >91.7%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow3_col4" class="data row3 col4" >100.0%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow3_col5" class="data row3 col5" >218</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow4_col0" class="data row4 col0" >DerivedVTM</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow4_col1" class="data row4 col1" >201819</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow4_col2" class="data row4 col2" >2799394</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow4_col3" class="data row4 col3" >30.6%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow4_col4" class="data row4 col4" >100.0%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow4_col5" class="data row4 col5" >684</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow5_col0" class="data row5 col0" >DerivedVTM</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow5_col1" class="data row5 col1" >201920</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow5_col2" class="data row5 col2" >3984198</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow5_col3" class="data row5 col3" >36.5%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow5_col4" class="data row5 col4" >100.0%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow5_col5" class="data row5 col5" >737</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow6_col0" class="data row6 col0" >DerivedVTMName</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow6_col1" class="data row6 col1" >201819</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow6_col2" class="data row6 col2" >2799394</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow6_col3" class="data row6 col3" >30.6%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow6_col4" class="data row6 col4" >0.0%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow6_col5" class="data row6 col5" >682</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow7_col0" class="data row7 col0" >DerivedVTMName</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow7_col1" class="data row7 col1" >201920</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow7_col2" class="data row7 col2" >3984198</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow7_col3" class="data row7 col3" >36.5%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow7_col4" class="data row7 col4" >0.0%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow7_col5" class="data row7 col5" >736</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow8_col0" class="data row8 col0" >DispensingRoute</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow8_col1" class="data row8 col1" >201819</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow8_col2" class="data row8 col2" >2799394</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow8_col3" class="data row8 col3" >12.4%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow8_col4" class="data row8 col4" >97.7%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow8_col5" class="data row8 col5" >235</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow9_col0" class="data row9 col0" >DispensingRoute</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow9_col1" class="data row9 col1" >201920</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow9_col2" class="data row9 col2" >3984198</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow9_col3" class="data row9 col3" >24.6%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow9_col4" class="data row9 col4" >99.1%</td>
#                         <td id="T_a4a15dfa_7785_11eb_8fbe_0cdd24571c9frow9_col5" class="data ro

# %% [markdown]
# ## Variable discussion in detail - variables available to query in OpenSAFELY via study definitions

# %% [markdown]
# ### Patient ID, Financial Year and Financial Month
#
# The patient ID in the high cost drugs dataset is used to match the information from this dataset to other patient level data included in the OpenSAFELY environment. This ID allows OpenSAFELY users to include information from other data sources on the platform (e.g. hospital episodes or COVID-19 testing) in any analysis of high cost drugs use.
#
# The financial year and financial month variables in the high cost drugs dataset are stored seperately which makes time period analysis a little more complex then if this information was stored as one variable. The OpenSAFELY cohort extracter has been developed so that users can query dates easily and the translation from conventional date format to seperate financial year and financial month filters is done in the background of the OpenSAFELY cohort extractor.
#
# The high cost drugs dataset contains submissions from April 2018 to March 2021. However, there are only a small number of submissions for FY 2020/21 and these are prospective submissions - submitted before the patient had recieved the medicine. We would recommend that these records are ignored and not used in any analysis.
#
# - In FY 2018/19 there were 2.8 million submissions for 1.1 million unique patient IDs. The average number of submissions per patient over the year was 2.6.
#
# - In FY 2019/20 there were 4.0 million submissions for 1.3 million unique patient IDs. The average number of submission per patient over the year was 3.1.

# %%
# steps to get the correct filepath for the csv file and read in patient record summary
os.getcwd()
parentDirectory = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
path = "/released-output/"
filename = parentDirectory + path + "record_summary_20210216.csv"

cols = [
    "Unique Patient IDs",
    "Number of Records",
    "Number of NULL Patient IDs",
    "Financial Year",
    "Financial Month"]

patient_record_summary = pd.read_csv(filename, header = None, names = cols, index_col = False)
patient_record_summary = patient_record_summary.sort_values(["Financial Year", "Financial Month" ])
patient_record_summary = patient_record_summary[["Financial Year", "Financial Month", "Number of NULL Patient IDs", 
                                                "Unique Patient IDs", "Number of Records"]]
patient_record_summary["Average num of records per patient"] = patient_record_summary["Number of Records"] / patient_record_summary["Unique Patient IDs"]
patient_record_summary_1819_1920 = patient_record_summary[(patient_record_summary["Financial Year"] != 202021)]

# %%
agg_list = ["Unique Patient IDs", "Number of Records"]
FY_Summary = patient_record_summary_1819_1920.groupby(["Financial Year"])[agg_list].sum()
FY_Summary["Average num of records per patient"] = FY_Summary["Number of Records"] / FY_Summary["Unique Patient IDs"]
FY_Summary_1 = FY_Summary.style.format({'Average num of records per patient': "{:.2}"})
FY_Summary_1
# Out:
# <style  type="text/css" >
# </style><table id="T_882ea2c0_7786_11eb_b39a_0cdd24571c9f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Unique Patient IDs</th>        <th class="col_heading level0 col1" >Number of Records</th>        <th class="col_heading level0 col2" >Average num of records per patient</th>    </tr>    <tr>        <th class="index_name level0" >Financial Year</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_882ea2c0_7786_11eb_b39a_0cdd24571c9flevel0_row0" class="row_heading level0 row0" >201819</th>
#                         <td id="T_882ea2c0_7786_11eb_b39a_0cdd24571c9frow0_col0" class="data row0 col0" >1064279</td>
#                         <td id="T_882ea2c0_7786_11eb_b39a_0cdd24571c9frow0_col1" class="data row0 col1" >2799394</td>
#                         <td id="T_882ea2c0_7786_11eb_b39a_0cdd24571c9frow0_col2" class="data row0 col2" >2.6</td>
#             </tr>
#             <tr>
#                         <th id="T_882ea2c0_7786_11eb_b39a_0cdd24571c9flevel0_row1" class="row_heading level0 row1" >201920</th>
#                         <td id="T_882ea2c0_7786_11eb_b39a_0cdd24571c9frow1_col0" class="data row1 col0" >1286804</td>
#                         <td id="T_882ea2c0_7786_11eb_b39a_0cdd24571c9frow1_col1" class="data row1 col1" >3984198</td>
#                         <td id="T_882ea2c0_7786_11eb_b39a_0cdd24571c9frow1_col2" class="data row1 col2" >3.1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Drug Name
#
# The drug name variable is a mandatory part of the submission (where relevant) and can be used in OpenSAFELY study defintions to provide information on the high cost drugs a patient has been prescribed in a given time period. This variable can be queried to produce:
# * A flag to indicate a patient was ever prescribed a medicine between two dates.
# * The first date a patient was prescribed a medicine between two dates.
# * The last date a patient was prescribed a medicine between two dates.
#
# This variable is populated for 99% of records.
#
# Where hospital systems use the dm+d drug definitions the drug name variable should be the dm+d drug name, if hospitals do not use the dm+d drug definitions this is a free text input, as described in the [submission data specification](https://datadictionary.nhs.uk/data_elements/drug_name__high_cost_tariff_excluded_drug_.html).
# When reviewing the unique values for the drug name variable it is clear that the range of values is very varied and the majority are not in the dm+d format. There are almost 21,000 unique values for the drug name variable in FY 2018/19 and almost 20,000 in FY 2019/20.
#
# This variation in recording of drug names means that codelists cannot be created using existing data definitions (e.g. dm+d or BNF) and bespoke "codelists" will need to be created to pick up all possible variants. To date these codelists have been created by searching to see if a string or set of strings is part of the drug name.
#
# Taking the medicine adalimumab as an example, there are over 460 different ways that adalimumab is described in the high cost drugs dataset. This variation is listed in Table three below, the high cost drugs adalimumab codelist.

# %%
# steps to get the correct filepath for the csv file and read in adalimumab codelist
os.getcwd()
parentDirectory = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
path = "/codelists/"
filename = parentDirectory + path + "opensafely-high-cost-drugs-adalimumab.csv"

adalimumab_codelist = pd.read_csv(filename, index_col = False)

# %% [markdown]
# ### Table three: High cost drugs adalimumab codelist

# %%
# table showing all adalimumab drug names from codelist
pd.set_option('display.max_rows', 500)
adalimumab_codelist
# Out:
#                                            olddrugname
# 0    (hca) adalimumab 40mg/0.8ml pre filled pen (im...
# 1                                    (home) adalimumab
# 2                           (home) humira (adalimumab)
# 3                          (home) imraldi (adalimumab)
# 4                                           adalimumab
# 5                                           adalimumab
# 6                     adalimumab - amgevita (homecare)
# 7                               adalimumab - biosmilar
# 8                      adalimumab - homecare 40 mg pen
# 9                       adalimumab - homecare delivery
# 10                               adalimumab - humira
# 11                     adalimumab - humira  (homecare)
# 12                      adalimumab - humira (homecare)
# 13      adalimumab - humira pen 80mg/0.8ml    20013015
# 14                                adalimumab - imraldi
# 15                               adalimumab - imraldi
# 16   adalimumab - imraldi (homecare- hidr. supp. in...
# 17                     adalimumab - imraldi (homecare)
# 18     adalimumab   amgevita 40mg 0.8ml pre filled pen
# 19   adalimumab   amgevita 40mg 0.8ml pre filled pe...
# 20   adalimumab   amgevita 40mg 0.8ml pre filledsyr...
# 21    adalimumab  (imraldi) **homecare delivery only**
# 22                 adalimumab  amgevita (homecare) pen
# 23                                     adalimumab  pen
# 24                  adalimumab ! humira pen 40mg/0.4ml
# 25             adalimumab ! humira syringe  40mg/0.4ml
# 26                    adalimumab ! humira syringe 40mg
# 27                       adalimumab $ (humira) pen*hc*
# 28                         adalimumab $ pen *homecare*
# 29                        adalimumab $(humira) syr*hc*
# 30                                       adalimumab ()
# 31                               adalimumab (amgevita)
# 32                          adalimumab (amgevita)  pen
# 33                      adalimumab (amgevita)  syringe
# 34               adalimumab (amgevita) (home delivery)
# 35         adalimumab (amgevita) (home delivery) (g-s)
# 36                    adalimumab (amgevita) (homecare)
# 37   adalimumab (amgevita) (pre-filled pens) 40 mg inj
# 38   adalimumab (amgevita) (pre-filled pens) 40 mg ...
# 39    adalimumab (amgevita) (pre-filled syringe) 20 mg
# 40   adalimumab (amgevita) (pre-filled syringe) 20 ...
# 41    adalimumab (amgevita) (pre-filled syringe) 40 mg
# 42   adalimumab (amgevita) (pre-filled syringe) 40 ...
# 43    adalimumab (amgevita) **homecare delivery only**
# 44       adalimumab (amgevita) 20 mg prefilled syringe
# 45   adalimumab (amgevita) 40 mg in 0.8ml prefilled...
# 46   adalimumab (amgevita) 40 mg in 0.8ml prefilled...
# 47   adalimumab (amgevita) 40mg/0.8ml pen (2) (home...
# 48     adalimumab (amgevita) pens (home delivery only)
# 49                adalimumab (amgevita) pre-filled pen
# 50            adalimumab (amgevita) pre-filled syringe
# 51                            adalimumab (amgevita)* ^
# 52                 adalimumab (amgevita)40mg/0.8ml pen
# 53                                    adalimumab (ccg)
# 54    adalimumab (d2e7) - homecare 40 mg preloaded pen
# 55   adalimumab (d2e7) - homecare 40 mg subcutaneou...
# 56    adalimumab (d2e7) - homecare 80 mg preloaded pen
# 57               adalimumab (d2e7) 40 mg preloaded pen
# 58      adalimumab (d2e7) 40 mg subcutaneous injection
# 59   adalimumab (discounted)!40mg/0.4ml!pre-filled pen
# 60                              adalimumab (for 'hs')
# 61   adalimumab (for hs) - homecare 40 mg preloaded...
# 62                          adalimumab (home delivery)
# 63           adalimumab (home) 40mg in 0.4ml injection
# 64           adalimumab (home) 40mg in 0.8ml injection
# 65                      adalimumab (homecare (humira))
# 66                      adalimumab (homecare (humira))
# 67                      adalimumab (homecare pen pack)
# 68                  adalimumab (homecare syringe pack)
# 69                               adalimumab (homecare)
# 70                               adalimumab (homecare)
# 71                      adalimumab (homecare) (for hs)
# 72             adalimumab (homecare) ^ 40 mg injection
# 73                adalimumab (homecare) hs dermatology
# 74   adalimumab (homecare), injection,40mg/0.4ml, 1...
# 75                         adalimumab (humira * hs * )
# 76              adalimumab (humira * hs * ) (homecare)
# 77            adalimumab (humira for homecare therapy)
# 78                                 adalimumab (humira)
# 79                                 adalimumab (humira)
# 80                                 adalimumab (humira)
# 81                                 adalimumab (humira)
# 82            adalimumab (humira) - homecare 40 mg pen
# 83                 adalimumab (humira) (home delivery)
# 84   adalimumab (humira) (home delivery) 40 mg in 0...
# 85   adalimumab (humira) (home delivery) 40 mg pre-...
# 86                      adalimumab (humira) (homecare)
# 87     adalimumab (humira) (homecare) (pre-filled pen)
# 88   adalimumab (humira) (homecare) 40 mg injection...
# 89       adalimumab (humira) (homecare) hs dermatology
# 90           adalimumab (humira) (pen) 40 mg injection
# 91                adalimumab (humira) (pre-filled pen)
# 92                adalimumab (humira) (pre-filled pen)
# 93                adalimumab (humira) (pre-filled pen)
# 94     adalimumab (humira) (pre-filled pen) (homecare)
# 95   adalimumab (humira) (pre-filled pens) 40 mg injec
# 96   adalimumab (humira) (pre-filled syringe) 40 mg in
# 97   adalimumab (humira) (pre-filled syringe) 40 mg...
# 98      adalimumab (humira) **homecare delivery only**
# 99   adalimumab (humira) [homecare]  (gastro) (syri...
# 100  adalimumab (humira) [homecare] (derm h/s only)...
# 101  adalimumab (humira) [homecare] (dermatology) (...
# 102  adalimumab (humira) [homecare] (gastro) (pen) ...
# 103        adalimumab (humira) 20 mg prefilled syringe
# 104  adalimumab (humira) 40 mg in 0.4ml pre-filled ...
# 105  adalimumab (humira) 40 mg in 0.4ml pre-filled pen
# 106  adalimumab (humira) 40 mg in 0.4ml pre-filled ...
# 107   adalimumab (humira) 40 mg in 0.4ml prefilled pen
# 108  adalimumab (humira) 40 mg in 0.4ml prefilled s...
# 109                adalimumab (humira) 40 mg injection
# 110                adalimumab (humira) 40 mg injection
# 111            adalimumab (humira) 40 mg injection pen
# 112           adalimumab (humira) 40 mg pre-filled pen
# 113       adalimumab (humira) homecare (hs indication)
# 114                            adalimumab (humira) pen
# 115                 adalimumab (humira) pre-filled pen
# 116  adalimumab (humira) pre-filled pen 40 mg subcu...
# 117             adalimumab (humira) pre-filled syringe
# 118  adalimumab (humira) pre-filled syringe 40 mg i...
# 119  adalimumab (humira) pre-filled syringe 40 mg s...
# 120                        adalimumab (humira) syringe
# 121  adalimumab (humira)(home) 40mg in 0.4ml injection
# 122  adalimumab (humira)_(homecare) 20 mg in 0.2ml ...
# 123  adalimumab (humira)_(homecare) 40 mg in 0.4ml ...
# 124  adalimumab (humira)_(homecare) 40 mg in 0.4ml ...
# 125                              adalimumab (hyrimoz )
# 126                   adalimumab (hyrimoz ) (homecare)
# 127   adalimumab (hyrimoz ) (homecare) reference price
# 128    adalimumab (hyrimoz ) (homecare)reference price
# 129            adalimumab (hyrimoz ) (reference price)
# 130        adalimumab (hyrimoz ) reference cost charge
# 131                               adalimumab (hyrimoz)
# 132  adalimumab (hyrimoz) (hhome) 40 mg pre-filled pen
# 133               adalimumab (hyrimoz) (home delivery)
# 134   adalimumab (hyrimoz) (pre-filled pen) (homecare)
# 135              adalimumab (hyrimoz) (pre filled pen)
# 136          adalimumab (hyrimoz) 40 mg pre-filled pen
# 137  adalimumab (hyrimoz) pre-filled pen 40 mg subc...
# 138  adalimumab (hyrimoz) pre-filled syringe 40 mg ...
# 139  adalimumab (hyrimoz)(home) 40 mg in 0.8ml pre-...
# 140                    adalimumab (imraldi biosimilar)
# 141          adalimumab (imraldi for homecare therapy)
# 142                               adalimumab (imraldi)
# 143                              adalimumab (imraldi)
# 144               adalimumab (imraldi) (home delivery)
# 145  adalimumab (imraldi) (home delivery) 40 mg in ...
# 146  adalimumab (imraldi) (home delivery) 40 mg pre...
# 147                    adalimumab (imraldi) (homecare)
# 148  adalimumab (imraldi) (pre-filled pens) 40 mg i...
# 149  adalimumab (imraldi) [homecare] (rheumatology)...
# 150  adalimumab (imraldi) 40 mg in 0.8ml pre-filled...
# 151     adalimumab (imraldi) pens (home delivery only)
# 152  adalimumab (imraldi) pre- filled syringe (home...
# 153                adalimumab (imraldi) pre-filled pen
# 154                adalimumab (imraldi) pre-filled pen
# 155            adalimumab (imraldi) pre-filled syringe
# 156                          adalimumab (imraldi)$ pen
# 157                     adalimumab (imraldi)40mg/0.8ml
# 158                                   adalimumab (pen)
# 159       adalimumab (pen) (hhome) 40 mg injection pen
# 160  adalimumab (pen) (humira) (hhome) 40 mg inject...
# 161  adalimumab (pen) 40 mg injection 2 x 40mg pref...
# 162                        adalimumab (pre-filled pen)
# 163             adalimumab (pre-filled pen) (homecare)
# 164       adalimumab (pre-filled pens) 40 mg injection
# 165                    adalimumab (pre-filled syringe)
# 166    adalimumab (pre-filled syringe) 40 mg injection
# 167              adalimumab **homecare delivery only**
# 168  adalimumab [amgevita] (homecare) 20 mg/0.4ml s...
# 169  adalimumab [amgevita] (homecare) 40 mg/0.8ml s...
# 170  adalimumab [amgevita] (homecare) 40 mg/0.8ml s...
# 171  adalimumab [amgevita] 20 mg/0.2ml soln for inj...
# 172  adalimumab [amgevita] 20 mg/0.4ml soln for inj...
# 173  adalimumab [amgevita] 40 mg/0.8ml soln for inj...
# 174  adalimumab [amgevita] 40 mg/0.8ml soln for inj...
# 175  adalimumab [humira] (homecare) 20 mg/0.2ml sol...
# 176  adalimumab [humira] (homecare) 40 mg solution ...
# 177  adalimumab [humira] (homecare) 40 mg/0.4ml sol...
# 178  adalimumab [humira] (homecare) 40 mg/0.4ml sol...
# 179  adalimumab [humira] 40 mg/0.4ml soln for injec...
# 180  adalimumab [imraldi] (homecare) 40 mg/0.8ml so...
# 181  adalimumab [imraldi] (homecare) 40 mg/0.8ml so...
# 182  adalimumab [imraldi] (homecare) 40 mg/0.8ml so...
# 183  adalimumab [imraldi] 40 mg/0.8ml soln for inje...
# 184  adalimumab [imraldi] 40 mg/0.8ml soln for inje...
# 185                 adalimumab 20 mg prefilled syringe
# 186         adalimumab 20mg syringe (humira)(homecare)
# 187           adalimumab 20mg/0.2ml pre-filled syringe
# 188  adalimumab 40 mg/0.4ml soln for inject pf syri...
# 189                                    adalimumab 40mg
# 190                           adalimumab 40mg homecare
# 191                  adalimumab 40mg homecare amgevita
# 192  adalimumab 40mg/0.4ml pen (humira) via homecar...
# 193               adalimumab 40mg/0.4ml pre-filled pen
# 194           adalimumab 40mg/0.4ml pre-filled pen (2)
# 195  adalimumab 40mg/0.4ml pre-filled pen humira (h...
# 196           adalimumab 40mg/0.4ml pre-filled syringe
# 197  adalimumab 40mg/0.4ml solution for injection p...
# 198  adalimumab 40mg/0.4ml solution for injection p...
# 199  adalimumab 40mg/0.4ml solution for injection p...
# 200  adalimumab 40mg/0.4ml solution for injection p...
# 201  adalimumab 40mg/0.4ml solution for injection p...
# 202      adalimumab 40mg/0.4ml!pre-filled pen (humira)
# 203  adalimumab 40mg/0.4ml!pre-filled syringe (humira)
# 204                              adalimumab 40mg/0.8ml
# 205  adalimumab 40mg/0.8ml pen (amgevita)(2x0.8ml)(...
# 206  adalimumab 40mg/0.8ml pf pen (hyrimoz) (2) via...
# 207               adalimumab 40mg/0.8ml pre-filled pen
# 208  adalimumab 40mg/0.8ml pre-filled pen (amgevita...
# 209  adalimumab 40mg/0.8ml pre-filled pen (homecare...
# 210  adalimumab 40mg/0.8ml pre-filled pen (humira)(...
# 211  adalimumab 40mg/0.8ml pre-filled pen (imraldi)...
# 212  adalimumab 40mg/0.8ml solution for injection p...
# 213  adalimumab 40mg/0.8ml solution for injection p...
# 214  adalimumab 40mg/0.8ml solution for injection p...
# 215  adalimumab 40mg/0.8ml solution for injection p...
# 216  adalimumab 40mg/0.8ml solution for injection v...
# 217    adalimumab 40mg/0.8ml!pre-filled pen (amgevita)
# 218     adalimumab 40mg/0.8ml!pre-filled pen (imraldi)
# 219  adalimumab Ã¡(imraldi) **homecare delivery only**
# 220                     adalimumab amgevita (1 x 0.8ml
# 221         adalimumab amgevita (1 x 0.8ml prefilled )
# 222                     adalimumab amgevita (homecare)
# 223  adalimumab amgevita 40 mg injection pre filled...
# 224  adalimumab for hidradenitis suppurativa (humir...
# 225                adalimumab homecare (hs indication)
# 226                     adalimumab hs (humira)$pen*hc*
# 227                               adalimumab humira ()
# 228                       adalimumab humira (homecare)
# 229                   adalimumab humira (homecare) pen
# 230   adalimumab humira 40 mg injection pre filled pen
# 231                      adalimumab hyrimoz (homecare)
# 232                          adalimumab hyrimoz pen ()
# 233                      adalimumab hyrimoz syringe ()
# 234  adalimumab imraldi 40 mg injection pre filled pen
# 235  adalimumab imraldi 40 mg injection prefilled s...
# 236                                     adalimumab pen
# 237                         adalimumab pen $*homecare*
# 238                          adalimumab pen (amgevita)
# 239  adalimumab pen (amgevita) 40 mg in 0.8ml injec...
# 240                            adalimumab pen (humira)
# 241   adalimumab pen (humira) 40 mg in 0.4ml injection
# 242                     adalimumab pen *homecare* 40mg
# 243                     adalimumab pen 40 mg injection
# 244  adalimumab pfs (amgevita) 40 mg subcutaneous i...
# 245                         adalimumab pfs (for 'hs')
# 246                 adalimumab pfs homecare (amgevita)
# 247  adalimumab pfs homecare (amgevita) 40 mg subcu...
# 248                   adalimumab pfs homecare (humira)
# 249  adalimumab pfs homecare (humira) 40 mg subcuta...
# 250  adalimumab pfs homecare 40 mg subcutaneous inj...
# 251                          adalimumab pre-filled pen
# 252    adalimumab pre-filled pen  40mg/0.4ml injection
# 253          adalimumab pre-filled pen 40 mg injection
# 254  adalimumab pre-filled syringe 40 mg in 0.4ml i...
# 255      adalimumab pre-filled syringe 40 mg injection
# 256                               adalimumab ref price
# 257                         adalimumab reference price
# 258            adalimumab sub-cutaneous injection 40mg
# 259                     adalimumab syringe $*homecare*
# 260                      adalimumab syringe (amgevita)
# 261  adalimumab syringe (amgevita) 20 mg in 0.4ml i...
# 262  adalimumab syringe (amgevita) 40 mg in 0.8ml i...
# 263                      adalimumab syringe (homecare)
# 264                      adalimumab syringe *homecare*
# 265           adalimumab!20mg/0.2ml!pre-filled syringe
# 266                  adalimumab!40mg!preloaded pen (1)
# 267            adalimumab!40mg/0.4ml!injection (1 pfp)
# 268               adalimumab!40mg/0.4ml!pre-filled pen
# 269           adalimumab!40mg/0.4ml!pre-filled pen (2)
# 270      adalimumab!40mg/0.4ml!pre-filled pen (humira)
# 271           adalimumab!40mg/0.4ml!pre-filled syringe
# 272           adalimumab!40mg/0.8ml!injection (1 vial)
# 273  adalimumab!40mg/0.8ml!pen (amgevita)(2x0.8ml)(...
# 274               adalimumab!40mg/0.8ml!pre-filled pen
# 275  adalimumab!40mg/0.8ml!pre-filled pen (humira)(...
# 276     adalimumab!40mg/0.8ml!pre-filled pen (imraldi)
# 277  adalimumab!40mg/0.8ml!pre-filled pen (imraldi)...
# 278                               adalimumab(amgevita)
# 279                                 adalimumab(humira)
# 280                                 adalimumab(humira)
# 281                                      adalimumab_hc
# 282                                           amgevita
# 283                                           amgevita
# 284            amgevita (homecare pen pack) adalimumab
# 285  amgevita 40mg/0.8ml solution for injection pre...
# 286  amgevita 40mg/0.8ml solution for injection pre...
# 287           amgevita pfs 40mg                9004607
# 288                       amgevita sure click pen 40mg
# 289             amgevita sure click pen 40mg   9004699
# 290           amgevita sure click pen 40mg   9004699
# 291                              amgevita topup charge
# 292                                       h adalimumab
# 293             h adalimumab (amgevita) pre-filled pen
# 294         h adalimumab (amgevita) pre-filled syringe
# 295                              h adalimumab (humira)
# 296           h adalimumab (humira) pre-filled syringe
# 297                  h adalimumab (pre-filled syringe)
# 298                         hc - adalimumab (amgevita)
# 299                         hc - adalimumab (amgevita)
# 300                           hc - adalimumab (humira)
# 301                          hc - adalimumab (imraldi)
# 302                          hc - adalimumab (imraldi)
# 303              hc adalimumab (amgevita) 40 mg penset
# 304  hc adalimumab (amgevita) 40mg/0.8ml prefilled ...
# 305                   hc adalimumab (hyrimoz) 40mg pen
# 306       hc adalimumab 40 mg injection pre filled pen
# 307                 hc adalimumab 40 mg injection vial
# 308  hc adalimumab amgevita 40 mg injection pre fil...
# 309  hc adalimumab amgevita 40 mg injection prefill...
# 310      hc adalimumab amgevita 40 mg sureclick device
# 311  hc adalimumab humira 40 mg injection pre fille...
# 312  hc adalimumab humira 40 mg injection prefilled...
# 313  hc adalimumab hyrimoz 40 mg injection pre fill...
# 314  hc adalimumab imraldi 40 mg injection pre fill...
# 315  hc adalimumab imraldi 40 mg injection prefille...
# 316        hd_adalimumab 40mg/0.4ml pre-filled pen (2)
# 317  home-adalimumab 40mg-0.8ml pf pen(amgevita)(0....
# 318  home-adalimumab 40mg/0.8ml pf pen(amgevita)(0....
# 319  home - adalimumab 40mg-0.8ml pf  pen (amgevita...
# 320  home - adalimumab 40mg  -0.8ml pf  pen (amgevi...
# 321  home - adalimumab 40mg/0.8ml pf  pen (amgevita...
# 322  home - adalimumab 40mg/0.8ml pf pen amgevita0.8ml
# 323  home - adalimumab 40mg/0.8ml pf pen(amgevita)0...
# 324    home adalimumab 40mg-0.4ml pen (derm - hs only)
# 325   home adalimumab 40mg-0.8ml pf syringe (amgevita)
# 326  home adalimumab 40mg-0.8ml pf syringe (amgevita)
# 327  home adalimumab 40mg  -0.8ml pf syringe (amgev...
# 328  home adalimumab 40mg  -0.8ml pf syringe (amgev...
# 329    home adalimumab 40mg/0.4ml pen (derm - hs only)
# 330   home adalimumab 40mg/0.8ml pf syringe (amgevita)
# 331  home adalimumab 40mg/0.8ml pf syringe (amgevita)
# 332        home adalimumab inj 40mg/0.4ml pen (humira)
# 333        home adalimumab inj 40mg/0.4ml pen (humira)
# 334        home adalimumab inj 40mg/0.4ml pfs (humira)
# 335         home adalimumab inj40mg/0.4ml pen (humira)
# 336  home adalimumab injection 40mg-0.4ml pen (humira)
# 337  home adalimumab injection 40mg-0.4ml pfs (humira)
# 338  home adalimumab injection 40mg  -0.4ml pen (hu...
# 339  home adalimumab injection 40mg  -0.4ml pfs (hu...
# 340  home adalimumab injection 40mg/0.4ml pen (humira)
# 341  home adalimumab injection 40mg/0.4ml pfs (humira)
# 342  homecare - adalimumab  pre-filled syringe 40 m...
# 343                   homecare - adalimumab (amgevita)
# 344  homecare - adalimumab (amgevita) (homecare) 20 mg
# 345  homecare - adalimumab (amgevita) (homecare) 40 mg
# 346  homecare - adalimumab (amgevita) 20 mg prefill...
# 347  homecare - adalimumab (amgevita) 40 mg in 0.8m...
# 348  homecare - adalimumab (amgevita) 40 mg in 0.8m...
# 349  homecare - adalimumab (amgevita) 40 mg prefill...
# 350  homecare - adalimumab (amgevita) 40 mg prefill...
# 351  homecare - adalimumab (homecare) (amgevita) 20 mg
# 352  homecare - adalimumab (homecare) (amgevita) 40 mg
# 353  homecare - adalimumab (homecare) (humira) 20 mg p
# 354  homecare - adalimumab (homecare) (humira) 20 m...
# 355  homecare - adalimumab (homecare) 20 mg pre-filled
# 356                     homecare - adalimumab (humira)
# 357  homecare - adalimumab (humira) (homecare) 20 m...
# 358  homecare - adalimumab (humira) (homecare) 40 m...
# 359   homecare - adalimumab (humira) (pre-filled pens)
# 360  homecare - adalimumab (humira) (pre-filled pen...
# 361  homecare - adalimumab (humira) (pre-filled syring
# 362  homecare - adalimumab (humira) (pre-filled syr...
# 363  homecare - adalimumab (humira) 40 mg in 0.4ml ...
# 364  homecare - adalimumab (humira) 40 mg in 0.4ml ...
# 365     homecare - adalimumab (humira) 40 mg injection
# 366  homecare - adalimumab (humira) auto injector p...
# 367   homecare - adalimumab (humira) prefilled syringe
# 368  homecare - adalimumab (humira) prefilled syrin...
# 369  homecare - adalimumab (pre-filled pens) 40 mg inj
# 370  homecare - adalimumab (pre-filled pens) 40 mg ...
# 371   homecare - adalimumab (pre-filled syringe) 40 mg
# 372  homecare - adalimumab (pre-filled syringe) 40 ...
# 373      homecare - adalimumab 20 mg prefilled syringe
# 374  homecare - adalimumab 40 mg in 0.8ml auto inje...
# 375  homecare - adalimumab 40 mg in 0.8ml prefilled...
# 376  homecare - adalimumab auto injector pen 40 mg ...
# 377                                homecare adalimumab
# 378                     homecare adalimumab (amgevita)
# 379    homecare adalimumab (amgevita) reference price^
# 380                       homecare adalimumab (humira)
# 381  homecare adalimumab (humira) 20 mg syringe 2 s...
# 382  homecare adalimumab (humira) 40 mg pre-filled ...
# 383  homecare adalimumab (humira) 40 mg pre-filled ...
# 384                      homecare adalimumab (imraldi)
# 385  homecare adalimumab 40mg injection (amgevita) (1)
# 386  homecare adalimumab 40mg injection (amgevita) ...
# 387  homecare adalimumab 40mg injection (amgevita) ...
# 388  homecare adalimumab 40mg injection (amgevita) ...
# 389    homecare adalimumab 40mg injection (humira) (1)
# 390  homecare adalimumab 40mg injection (humira) (1...
# 391  homecare adalimumab 40mg/0.4ml!pre-filled pen(...
# 392                            homecare adalimumab pen
# 393  homecare adalimumab pen (amgevita) 40 mg in 0....
# 394                   homecare adalimumab pen (humira)
# 395  homecare adalimumab pen (humira) 40 mg in 0.4m...
# 396  homecare adalimumab prefilled device - (humira...
# 397  homecare adalimumab prefilled device - (humira...
# 398  homecare adalimumab prefilled device - (hyrimo...
# 399  homecare adalimumab prefilled device - as pres...
# 400                        homecare adalimumab syringe
# 401  homecare adalimumab syringe (amgevita) 20 mg i...
# 402  homecare adalimumab syringe (amgevita) 40 mg i...
# 403               homecare adalimumab syringe (humira)
# 404  homecare adalimumab syringe (humira) 40 mg in ...
# 405  homecare adalimumab!40mg/0.4ml pre-filled pen (2)
# 406  homecare adalimumab!40mg/0.4ml pre-filled pen ...
# 407      homecare adalimumab!40mg/0.8ml! pen (hyrimoz)
# 408      homecare adalimumab!40mg/0.8ml!pen (amgevita)
# 409  homecare adalimumab!40mg/0.8ml!pen (hyrimoz) (hs)
# 410      homecare adalimumab!40mg/0.8ml!pfs (amgevita)
# 411  homecare adalimumab^ (amgevita) 40 mg pre-fill...
# 412                      homecare adalimumab^ (humira)
# 413  homecare adalimumab^ (humira) 40 mg pre-filled...
# 414                     homecare amgevita (adalimumab)
# 415  homecare amgevita (adalimumab) 40 mg pre-fille...
# 416  homecare amgevita (adalimumab) 40 mg pre-fille...
# 417                   homecare amgevita pen adalimumab
# 418               homecare amgevita syringe adalimumab
# 419                    homecare charge - adalimumab_hc
# 420                     homecare humira pen adalimumab
# 421                      homecare imraldi (adalimumab)
# 422  homecare imraldi (adalimumab) 40 mg pre-filled...
# 423  homecare imraldi (adalimumab) 40 mg pre-filled...
# 424                    homecare imraldi pen adalimumab
# 425                homecare imraldi syringe adalimumab
# 426                                             humira
# 427                                             humira
# 428                     humira (adalimumab) (homecare)
# 429              humira (homecare pen pack) adalimumab
# 430          humira (homecare syringe pack) adalimumab
# 431             humira (homecare) 40 mg pre-filled pen
# 432                         humira 40mg pen (homecare)
# 433  humira 40mg/0.4ml solution for injection pre-f...
# 434  humira 40mg/0.4ml solution for injection pre-f...
# 435  humira 40mg/0.4ml solution for injection pre-f...
# 436  humira 40mg/0.4ml solution for injection pre-f...
# 437  humira 40mg/0.4ml solution for injection pre-f...
# 438                                     humira pen <6>
# 439                        humira pen 40mg / 0.4ml <2>
# 440                        humira pen 40mg / 0.4ml <4>
# 441                        humira pen 40mg / 0.4ml <8>
# 442                              humira pen 40mg/0.4ml
# 443           humira pen 40mg/0.4ml
# 444                         humira syringe  40mg/0.4ml
# 445           humira syringe  40mg/0.4ml
# 446                          humira syringe 20mg/0.2ml
# 447                     humira(adalimumab)40mg pen [2]
# 448            hyrimoz (homecare) 40 mg pre-filled pen
# 449  hyrimoz40mg/0.8mlsolutionforinjectionpre-fille...
# 450                                            imraldi
# 451                               imraldi (adalimumab)
# 452             imraldi (homecare pen pack) adalimumab
# 453         imraldi (homecare syringe pack) adalimumab
# 454  imraldi 40mg/0.8ml solution for injection pre-...
# 455  imraldi 40mg/0.8ml solution for injection pre-...
# 456  imraldi 40mg/0.8ml solution for injection pre-...
# 457  imraldi 40mg/0.8ml solution for injection pre-...
# 458                                 imraldi adalimumab
# 459                               imraldi topup charge
# 460                  imraldi topup charge- amgevita m2
# 461           variable hcd - amgevita adalimumab (ccg)
# 462  variable hcd - amgevita adalimumab (ccg) - ris...
