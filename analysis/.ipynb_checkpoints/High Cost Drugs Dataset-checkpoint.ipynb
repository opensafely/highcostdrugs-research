# %% [markdown]
# **High cost drugs dataset**
#
# The high cost drugs dataset brings together high cost drugs patient level data submissions from all regional Data Services for Commissioners Regional Offices (DSCROs). The North of England Commisioning Support Unit (NECS) collected submissions from all Acute Providers and Commissioners nationally. The current dataset contains 6.8 million records.
#
# **Caveats**
# * The NECS are unable to say with any certainty that the data received is a complete data set for each Provider and Commissioner.
# * The drug names and other text inputs are non-standardised, further work is required to standardise variables in the dataset.
# * The NECS are unable to comment on the level of data validation that has been undertaken before it was submitted.
#
# Further information on the NECS data collation and cleaning processes can be found in [this document.](https://docs.google.com/document/d/1JbUPp962KRNGsIC1wThexdMUrV0XOb-D/edit#heading=h.gjdgxs)

# %% [markdown]
# **Meta data**
#
# The NECS provided a meta data file for the high cost drugs dataset, this is [saved here.](https://docs.google.com/spreadsheets/d/1i_Ux8UveZR8brMDO0-_TV_tYfWMLSSHY/edit?rtpof=true#gid=1394523185)
# The dataset includes the following variables:
# * Patient_ID
# * FinancialMonth
# * FinancialYear
# * PersonAge
# * PersonGender
# * ActivityTreatmentFunctionCode
# * TherapeuticIndicationCode
# * HighCostTariffExcludedDrugCode (2.54m records with NULL value)
# * DrugName (82k records with NULL value)
# * Route of Administration
# * DrugStrength
# * DrugVolume
# * DrugPackSize
# * DrugQuantityOrWeightProportion
# * UnitOfMeasurement
# * DispensingRoute
# * HomeDeliveryCharge
# * TotalCost
# * DerivedSNOMEDFromName (6.2m records with NULL value - very low coverage)
# * DerivedVTM (2.3m records with NULL value)
# * DerivedVTMName (2.3m records with NULL value)

# %% [markdown]
# **Time period covered by the dataset**
#
# The high cost drugs dataset covers data from April 2018 to March 2021. Most records appear between April 2018 and March 2020. We don't yet know why there are records from "the future" (beyond April 2020 at the time NECS collected the data submissions).

# %%
# bring in libraries
import pandas as pd
import numpy as np
import os

# steps to get the correct filepath for the csv file
os.getcwd()
parentDirectory = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
path = "/released-output/"
filename = parentDirectory + path + "year_month_info.csv"

cols = [
    "Year",
    "Financial Month",
    "Number of records"]

month_summary = pd.read_csv(filename, header = None, names = cols, index_col = False)
month_summary
# Out:
#       Year  Financial Month  Number of records
# 0   201819              NaN                885
# 1   201819              1.0             214294
# 2   201819              2.0             233206
# 3   201819              3.0             223959
# 4   201819              4.0             236186
# 5   201819              5.0             240151
# 6   201819              6.0             220098
# 7   201819              7.0             248774
# 8   201819              8.0             241963
# 9   201819              9.0             226459
# 10  201819             10.0             253798
# 11  201819             11.0             223724
# 12  201819             12.0             235897
# 13  201920              1.0             348493
# 14  201920              2.0             348764
# 15  201920              3.0             320146
# 16  201920              4.0             364961
# 17  201920              5.0             325621
# 18  201920              6.0             337673
# 19  201920              7.0             341881
# 20  201920              8.0             320123
# 21  201920              9.0             309418
# 22  201920             10.0             341280
# 23  201920             11.0             326870
# 24  201920             12.0             298968
# 25  202021              NaN               1127
# 26  202021              1.0              15612
# 27  202021              2.0                122
# 28  202021              3.0                100
# 29  202021              4.0                 91
# 30  202021              5.0                110
# 31  202021              6.0                 92
# 32  202021              7.0                 99
# 33  202021              8.0                103
# 34  202021              9.0                100
# 35  202021             10.0               2219
# 36  202021             11.0               2149
# 37  202021             12.0               1699

# %% [markdown]
# **Non standardised drug names**
#
# The drug names in the high cost drugs dataset are not in the dm+d format. From looking at some examples it looks like during the data input drug names can be entered as free text and there can be many different variations for a single medicine.
#
# Using adalimumab as an example - the code below lists all the unique drug names which contain the word "adalimumab". There are 427 unique drug names (with variations on upper and lower case characters).
#
# Bespoke code lists will be required to pick up all relevant medicines use from the high cost drugs dataset in it's current form - it is not going to be enough to search on dm+d values alone.

# %%
# steps to get the correct filepath for the csv file
os.getcwd()
parentDirectory = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
path = "/released-output/"
filename = parentDirectory + path + "drug_name_summary.csv"

# reading in data summary and setting column names
cols = [
    "DrugName",
    "HighCostTariffExcludedDrugCode",
    "DerivedSNOMEDFromName",
    "DerivedVTM",
    "DerivedVTMName",
    "NumberOfAppearances"]

drug_name_summary = pd.read_csv(filename, header = None, names = cols, index_col = False)
searchfor = ['adalimumab', 'Adalimumab', "ADALIMUMAB"]

adalimumab = drug_name_summary[drug_name_summary['DrugName'].str.contains('|'.join(searchfor),na = False)] 

adalimumab_drugname_unique = adalimumab.DrugName.unique()
len(adalimumab_drugname_unique)
# Out:
# 427

# %%
adalimumab_drugname_unique
# Out:
# array(['HC ADALIMUMAB IMRALDI 40 mg Injection Pre Filled Pen',
#        'ADALIMUMAB', 'ADALIMUMAB (D2E7) - HOMECARE 40 mg Preloaded Pen',
#        'ADALIMUMAB (IMRALDI) (HOMECARE)', 'ADALIMUMAB (IMRALDI) ',
#        'HC ADALIMUMAB HUMIRA 40 mg Injection Pre Filled Pen',
#        'Adalimumab 40mg/0.8ml solution for injection pre-filled disposable devices',
#        'HOMECARE ADALIMUMAB (IMRALDI)', 'ADALIMUMAB REFERENCE PRICE',
#        'HOMECARE IMRALDI (ADALIMUMAB)', 'ADALIMUMAB(AMGEVITA)',
#        'HOMECARE - ADALIMUMAB (AMGEVITA) 40 mg in 0.8ml Auto Injector Pen',
#        'ADALIMUMAB (HUMIRA)_(HOMECARE) 40 mg in 0.4mL Pre-filled Injection Pen',
#        'ADALIMUMAB (HUMIRA) (HOMECARE)', 'ADALIMUMAB(HUMIRA)',
#        'Adalimumab (Homecare)', 'Adalimumab',
#        'HOMECARE AMGEVITA (ADALIMUMAB)',
#        'HOMECARE ADALIMUMAB!40mg/0.8mL! PEN (HYRIMOZ)',
#        'IMRALDI (HOMECARE PEN PACK) ADALIMUMAB',
#        'ADALIMUMAB [IMRALDI] (HOMECARE) 40 mg/0.8mL Soln for Injection PF Pen',
#        'ADALIMUMAB (IMRALDI)', 'ADALIMUMAB (HUMIRA)',
#        'HOMECARE - ADALIMUMAB (AMGEVITA)',
#        'HC ADALIMUMAB AMGEVITA 40 mg Injection Pre Filled Pen',
#        'ADALIMUMAB(Humira)', 'ADALIMUMAB (IMRALDI) (HOME DELIVERY)',
#        'ADALIMUMAB 40MG/0.4ML SOLUTION FOR INJECTION PRE-FILLED DISPOSABLE DEVICES',
#        'ADALIMUMAB - IMRALDI (HOMECARE)', 'ADALIMUMAB (HOMECARE)',
#        'HC ADALIMUMAB IMRALDI 40 mg Injection Prefilled Syringe',
#        'HOMECARE - ADALIMUMAB (HUMIRA) 40 mg in 0.4ml Auto Injector Pen',
#        'ADALIMUMAB AMGEVITA (1 x 0.8ml Prefilled )',
#        'HOMECARE - ADALIMUMAB (HUMIRA)',
#        'ADALIMUMAB 40mg/0.8mL PRE-FILLED PEN (HOMECARE PATIENTS)',
#        'ADALIMUMAB (HUMIRA) (HOME DELIVERY) 40 mg in 0.4mL Pre-Filled Pen',
#        'ADALIMUMAB (AMGEVITA)',
#        'ADALIMUMAB [AMGEVITA] (HOMECARE) 40 mg/0.8mL Soln for Injection PF Pen',
#        'Adalimumab 40mg/0.8ml solution for injection vials',
#        'HOMECARE ADALIMUMAB (HUMIRA)',
#        'ADALIMUMAB (Imraldi) Pre-Filled Pen',
#        'ADALIMUMAB (homecare pen pack)',
#        'ADALIMUMAB (Humira) [HOMECARE] (GASTRO) (PEN) 40 mg Injection',
#        'ADALIMUMAB (HYRIMOZ)(HOME) 40 mg in 0.8ml Pre-filled Pen',
#        'ADALIMUMAB pre-filled pen', 'HC - ADALIMUMAB (Humira)',
#        'ADALIMUMAB 40mg/0.8mL PRE-FILLED PEN (IMRALDI)(2)HOMECAR',
#        'ADALIMUMAB 40MG/0.8ML SOLUTION FOR INJECTION PRE-FILLED DISPOSABLE DEVICES',
#        'ADALIMUMAB IMRALDI 40 mg Injection Pre Filled Pen',
#        'HOMECARE ADALIMUMAB!40mg/0.4ml PRE-FILLED PEN (2)',
#        'ADALIMUMAB - HUMIRA (HOMECARE)',
#        'Adalimumab 40mg/0.8ml solution for injection pre-filled syringes',
#        'HOME Adalimumab Injection 40mg-0.4ml PEN (Humira)',
#        'HOMECARE ADALIMUMAB (AMGEVITA)',
#        'HOMECARE ADALIMUMAB 40MG INJECTION (AMGEVITA) (1)',
#        'HOMECARE - ADALIMUMAB Auto Injector Pen 40 mg Injection',
#        'HC ADALIMUMAB HUMIRA 40 mg Injection Prefilled Syringe',
#        'H ADALIMUMAB (AMGEVITA) PRE-FILLED PEN', 'ADALIMUMAB_HC',
#        'HOME Adalimumab Injection 40mg/0.4ml PEN (Humira)',
#        'ADALIMUMAB - IMRALDI ', 'H ADALIMUMAB (HUMIRA)',
#        'Adalimumab ! HUMIRA PEN 40MG/0.4ML',
#        'ADALIMUMAB  AMGEVITA (HOMECARE) PEN',
#        'ADALIMUMAB (D2E7) - HOMECARE 40 mg Subcutaneous Injection',
#        'HOMECARE IMRALDI (ADALIMUMAB) 40 mg Pre-filled pen 2 x 40mg prefilled pen Pack',
#        'ADALIMUMAB 40MG/0.8ML SOLUTION FOR INJECTION PRE-FILLED SYRINGES',
#        'ADALIMUMAB [IMRALDI] (HOMECARE) 40 mg/0.8mL Soln for Inject PF Disp Device',
#        'H ADALIMUMAB',
#        'ADALIMUMAB (AMGEVITA) 40 mg in 0.8ml prefilled pen',
#        'ADALIMUMAB PFS HOMECARE (AMGEVITA)',
#        'HOMECARE IMRALDI PEN Adalimumab', 'adalimumab pen $*homecare*',
#        'HOMECARE - ADALIMUMAB (AMGEVITA) 40 mg prefilled pen',
#        'ADALIMUMAB (HUMIRA) **HOMECARE DELIVERY ONLY**',
#        'ADALIMUMAB (HOME) 40mg in 0.4ml Injection',
#        'Adalimumab (Hyrimoz) (Pre-filled pen) (Homecare)',
#        'Adalimumab - Biosmilar',
#        'Adalimumab 40mg/0.4ml solution for injection pre-filled syringes',
#        'HOMECARE ADALIMUMAB 40MG INJECTION (AMGEVITA) (1)Gain Share',
#        'ADALIMUMAB (HUMIRA) 40 mg Injection Pen',
#        'HOMECARE ADALIMUMAB (AMGEVITA) REFERENCE PRICE^',
#        'ADALIMUMAB (HOME) 40mg in 0.8ml Injection',
#        'Homecare Charge - ADALIMUMAB_HC',
#        'ADALIMUMAB [AMGEVITA] (HOMECARE) 20 mg/0.4mL Soln for Inject PF Syringes',
#        'ADALIMUMAB HYRIMOZ (HOMECARE)',
#        'HOME-ADALIMUMAB 40mg/0.8mL PF PEN(AMGEVITA)(0.8mL)',
#        'HOMECARE - ADALIMUMAB 20 mg prefilled syringe',
#        'ADALIMUMAB (HUMIRA)(HOME) 40mg in 0.4ml Injection',
#        'ADALIMUMAB (Humira)',
#        'ADALIMUMAB (AMGEVITA) 20 mg prefilled syringe', 'ADALIMUMAB ()',
#        'HUMIRA (homecare pen pack) ADALIMUMAB',
#        'ADALIMUMAB FOR HIDRADENITIS SUPPURATIVA (HUMIRA)_(HOMECARE) 40 mg in 0.4mL Pre-filled Injection Pen',
#        'ADALIMUMAB [HUMIRA] (HOMECARE) 40 mg/0.4mL Soln for Injection PF Pen',
#        'adalimumab pen *homecare* 40mg', 'adalimumab $ (humira) pen*HC*',
#        'ADALIMUMAB HUMIRA (HOMECARE) PEN',
#        'ADALIMUMAB (HUMIRA)_(HOMECARE) 40 mg in 0.4mL Pre-filled Syringe',
#        'ADALIMUMAB (IMRALDI) (HOME DELIVERY) 40 mg in 0.8mL Pre-Filled Pen',
#        'HOMECARE - ADALIMUMAB (HUMIRA) AUTO INJECTOR PEN 40 mg',
#        'ADALIMUMAB (AMGEVITA) (HOME DELIVERY)',
#        'adalimumab pre-filled pen  40mg/0.4ml injection',
#        'ADALIMUMAB AMGEVITA (1 x 0.8ml', 'ADALIMUMAB (HOME DELIVERY)',
#        'ADALIMUMAB HUMIRA ()',
#        'ADALIMUMAB (IMRALDI) PENS (HOME DELIVERY ONLY)',
#        'HUMIRA (ADALIMUMAB) (HOMECARE)',
#        'HOMECARE AMGEVITA (ADALIMUMAB) 40 mg Pre-filled pen 2 x 40mg prefilled pen Pack',
#        'HOMECARE - ADALIMUMAB (AMGEVITA) 40 mg in 0.8ml Prefilled Syringe',
#        'HOMECARE ADALIMUMAB 40MG INJECTION (AMGEVITA) (1)Gainshare',
#        'ADALIMUMAB (Imraldi) Pre-Filled Syringe',
#        'HOME-ADALIMUMAB 40mg-0.8mL PF PEN(AMGEVITA)(0.8mL)',
#        'ADALIMUMAB (HOMECARE (HUMIRA))',
#        'ADALIMUMAB (Humira) Pre-Filled Pen',
#        'H ADALIMUMAB (AMGEVITA) PRE-FILLED SYRINGE',
#        'HOMECARE ADALIMUMAB 40mg INJECTION (HUMIRA) (1)',
#        'ADALIMUMAB 20 mg prefilled syringe',
#        'HOMECARE - ADALIMUMAB 40 mg in 0.8ml Auto Injector Pen',
#        'ADALIMUMAB (HOMECARE) HS DERMATOLOGY',
#        'ADALIMUMAB (HUMIRA) 40 mg in 0.4ml prefilled pen',
#        'Adalimumab ! HUMIRA SYRINGE  40MG/0.4ML',
#        'HOMECARE ADALIMUMAB^ (HUMIRA) 40 mg Pre-filled Pen',
#        'ADALIMUMAB (HUMIRA) (HOMECARE) HS DERMATOLOGY',
#        'ADALIMUMAB (HUMIRA) (HOME DELIVERY)',
#        'ADALIMUMAB (Imraldi FOR HOMECARE THERAPY)',
#        'HOME - ADALIMUMAB 40mg-0.8mL PF  PEN (AMGEVITA)(0.8mL)',
#        'ADALIMUMAB (D2E7) 40 mg Preloaded Pen',
#        'HOMECARE - ADALIMUMAB (HUMIRA) 40 mg in 0.4ml Prefilled Syringe',
#        'ADALIMUMAB 40MG HOMECARE', 'ADALIMUMAB 40mg/0.8mL',
#        'HC - ADALIMUMAB (Imraldi)',
#        'HOMECARE - ADALIMUMAB (AMGEVITA) 20 mg prefilled syringe',
#        'ADALIMUMAB PFS HOMECARE (HUMIRA)',
#        'HomeCare - ADALIMUMAB (Homecare) (AMGEVITA) 40 mg',
#        'AMGEVITA (HOMECARE PEN PACK) ADALIMUMAB',
#        'ADALIMUMAB HYRIMOZ PEN ()',
#        'H ADALIMUMAB (HUMIRA) pre-filled syringe',
#        'ADALIMUMAB [AMGEVITA] 40 mg/0.8mL Soln for Injection PF Pen',
#        'Adalimumab (Pre-filled pen)',
#        'ADALIMUMAB (HUMIRA) 20 mg prefilled syringe',
#        'ADALIMUMAB [AMGEVITA] (HOMECARE) 40 mg/0.8mL Soln for Inject PF Disp Device',
#        'HOME Adalimumab Injection 40mg-0.4ml PFS (Humira)',
#        'ADALIMUMAB - AMGEVITA (HOMECARE)',
#        'ADALIMUMAB (AMGEVITA) (HOMECARE)', 'Adalimumab (CCG)',
#        'HOMECARE ADALIMUMAB!40mg/0.8mL!PEN (AMGEVITA)',
#        'ADALIMUMAB [IMRALDI] (HOMECARE) 40 mg/0.8mL Soln for Inject PF Syringes',
#        'ADALIMUMAB (D2E7) - HOMECARE 80 mg Preloaded Pen',
#        'ADALIMUMAB PFS HOMECARE 40 mg Subcutaneous Injection 1 Pre-Filled Syringe Pack',
#        'IMRALDI (HOMECARE SYRINGE PACK) ADALIMUMAB',
#        'ADALIMUMAB!40mg/0.8mL!PRE-FILLED PEN (IMRALDI)(2)HOMECAR',
#        'HOMECARE ADALIMUMAB^ (AMGEVITA) 40 mg Pre-filled P',
#        'ADALIMUMAB (AMGEVITA) 40mg/0.8ml PEN (2) (HOMECARE',
#        'ADALIMUMAB (HUMIRA * HS * ) (HOMECARE)',
#        'HOMECARE IMRALDI SYRINGE Adalimumab',
#        'H ADALIMUMAB (pre-filled syringe)',
#        'ADALIMUMAB 40MG HOMECARE AMGEVITA',
#        'HOMECARE ADALIMUMAB PREFILLED DEVICE - (HUMIRA) 40 mg Injection',
#        'HOME - ADALIMUMAB 40mg  -0.8mL PF  PEN (AMGEVITA)(0.8mL)',
#        'ADALIMUMAB [HUMIRA] (HOMECARE) 40 mg/0.4mL Soln for Inject PF Disp Device',
#        'ADALIMUMAB  (IMRALDI) **HOMECARE DELIVERY ONLY**',
#        'ADALIMUMAB (AMGEVITA) 40 mg in 0.8ml prefilled syringe',
#        'ADALIMUMAB 40mg/0.4mL!PRE-FILLED PEN (HUMIRA)',
#        'HOMECARE ADALIMUMAB (HUMIRA) 40 mg Pre-filled pen 2 x 40mg prefilled pen Pack',
#        'Adalimumab (Pre-filled pen) (Homecare)',
#        'HOMECARE ADALIMUMAB 40MG INJECTION (AMGEVITA) (1)G',
#        'ADALIMUMAB (Humira) [HOMECARE] (DERMATOLOGY) (PEN) 40 mg Injection',
#        'Adalimumab ! HUMIRA SYRINGE 40MG',
#        'HOME Adalimumab INJ 40mg/0.4ml PEN (Humira)',
#        'HC ADALIMUMAB AMGEVITA 40 mg Injection Prefilled Syringe',
#        'HOME - ADALIMUMAB 40mg/0.8mL PF  PEN (AMGEVITA)(0.8mL)',
#        'ADALIMUMAB (AMGEVITA) PRE-FILLED PEN',
#        'ADALIMUMAB (AMGEVITA) (PRE-FILLED SYRINGE) 40 mg I',
#        'HOMECARE ADALIMUMAB^ (HUMIRA)', 'Adalimumab (Humira)',
#        'ADALIMUMAB [IMRALDI] 40 mg/0.8mL Soln for Injection PF Pen',
#        'ADALIMUMAB AMGEVITA 40 mg Injection Pre Filled Pen',
#        'HOME Adalimumab 40mg/0.4ml PEN (DERM - HS ONLY)',
#        'ADALIMUMAB 40mg/0.8mL PRE-FILLED PEN',
#        'ADALIMUMAB!40mg/0.4mL!PRE-FILLED PEN',
#        'HomeCare - ADALIMUMAB (AMGEVITA) (HOMECARE) 40 mg',
#        'HOME Adalimumab Inj 40mg/0.4ml PEN (Humira)',
#        'HOMECARE - ADALIMUMAB  Pre-filled syringe 40 mg Injection',
#        'ADALIMUMAB (HOMECARE) ^ 40 mg Injection',
#        'HOMECARE IMRALDI (ADALIMUMAB) 40 mg Pre-filled syringe 2 x 40mg prefilled syringe Pack',
#        'ADALIMUMAB (HUMIRA) 40 mg in 0.4mL Pre-Filled Pen',
#        'Adalimumab Pen (Amgevita) 40 Mg In 0.8Ml Injection',
#        'ADALIMUMAB [AMGEVITA] 20 mg/0.4mL Soln for Inject PF Syringes',
#        'adalimumab (imraldi)40mg/0.8ml',
#        'ADALIMUMAB pre-filled pen 40 mg Injection', '(HOME) ADALIMUMAB',
#        'ADALIMUMAB (Humira) [HOMECARE]  (GASTRO) (SYRINGE) 40 mg Injection',
#        'ADALIMUMAB [HUMIRA] 40 mg/0.4mL Soln for Injection PF Pen',
#        'HomeCare - ADALIMUMAB (Homecare) (AMGEVITA) 20 mg',
#        'ADALIMUMAB (homecare syringe pack)',
#        'ADALIMUMAB (IMRALDI) PRE- FILLED SYRINGE (HOME DELIVERY)',
#        'Adalimumab (HOMECARE (HUMIRA))',
#        'HOMECARE - ADALIMUMAB (AMGEVITA) 40 mg prefilled syringe',
#        'HC ADALIMUMAB (AMGEVITA) 40 MG PENSET',
#        'ADALIMUMAB!40mg/0.8mL!PEN (AMGEVITA)(2x0.8mL)(HomeCare)',
#        'HOME ADALIMUMAB 40mg-0.8mL PF SYRINGE (AMGEVITA) ',
#        'HomeCare - ADALIMUMAB (PRE-FILLED SYRINGE) 40 mg I',
#        'ADALIMUMAB (HYRIMOZ) PRE-FILLED PEN 40 mg Subcutaneous Injection',
#        'adalimumab syringe *homecare*',
#        'HOMECARE ADALIMUMAB PREFILLED DEVICE - (HUMIRA) 40',
#        'adalimumab syringe $*homecare*',
#        'ADALIMUMAB!40mg/0.4mL!PRE-FILLED PEN (HUMIRA)',
#        'HomeCare - ADALIMUMAB (PRE-FILLED SYRINGE) 40 mg',
#        'ADALIMUMAB 40mg/0.8mL PRE-FILLED PEN (HUMIRA)(HOMECARE)',
#        'ADALIMUMAB [AMGEVITA] 40 mg/0.8mL Soln for Inject PF Syringes',
#        'ADALIMUMAB (HYRIMOZ) (HHOME) 40 mg Pre-Filled Pen',
#        'ADALIMUMAB - HUMIRA  (HOMECARE)',
#        'HOMECARE HUMIRA PEN Adalimumab',
#        'ADALIMUMAB (AMGEVITA) PRE-FILLED SYRINGE',
#        'HomeCare - ADALIMUMAB (HUMIRA) (PRE-FILLED SYRING',
#        'ADALIMUMAB [HUMIRA] (HOMECARE) 20 mg/0.2mL Soln for Inject PF Syringes',
#        'ADALIMUMAB - HUMIRA  ', 'ADALIMUMAB!40mg/0.4mL!INJECTION (1 PFP)',
#        'HOMECARE ADALIMUMAB!40mg/0.4ml PRE-FILLED PEN (2)(STAFF)',
#        'ADALIMUMAB (AMGEVITA) (PRE-FILLED SYRINGE) 20 mg I',
#        'ADALIMUMAB (HUMIRA) (Homecare) (Pre-Filled Pen)',
#        'ADALIMUMAB 40mg/0.8mL PEN (AMGEVITA)(2x0.8mL)(HomeCare)',
#        'ADALIMUMAB (AMGEVITA)  PEN',
#        'ADALIMUMAB SUB-CUTANEOUS INJECTION 40mg',
#        'HOMECARE - ADALIMUMAB (HUMIRA) PREFILLED SYRINGE',
#        'HOME Adalimumab Injection 40mg/0.4ml PFS (Humira)',
#        'ADALIMUMAB 40mg/0.4mL PRE-FILLED PEN',
#        'ADALIMUMAB pre-filled syringe 40 mg in 0.4ml Injection',
#        'ADALIMUMAB (HUMIRA) Pen',
#        'HomeCare - ADALIMUMAB (Homecare) (HUMIRA) 20 mg P',
#        'HOMECARE AMGEVITA SYRINGE Adalimumab',
#        'ADALIMUMAB (AMGEVITA) (PRE-FILLED PENS) 40 mg Inje',
#        'ADALIMUMAB - HOMECARE DELIVERY',
#        'Homecare Adalimumab Pen (Amgevita) 40 Mg In 0.8Ml Injection',
#        'HOME ADALIMUMAB 40mg/0.8mL PF SYRINGE (AMGEVITA) ',
#        '(HOME) IMRALDI (ADALIMUMAB)', 'Homecare Adalimumab Pen',
#        'ADALIMUMAB (HUMIRA) 40 mg in 0.4ml prefilled syringe',
#        'HC ADALIMUMAB AMGEVITA 40 mg SURECLICK DEVICE',
#        'ADALIMUMAB (Pen)', 'HOMECARE AMGEVITA PEN Adalimumab',
#        'ADALIMUMAB (PEN) (HHOME) 40 mg Injection Pen',
#        'ADALIMUMAB (Humira) (PEN) 40 mg Injection',
#        '(HCA) ADALIMUMAB 40mg/0.8ml PRE FILLED PEN (IMRALDI) (2)',
#        'HOME ADALIMUMAB 40mg/0.8mL PF SYRINGE (AMGEVITA)',
#        'ADALIMUMAB (HUMIRA) (PRE-FILLED SYRINGE) 40 mg In',
#        'HomeCare - ADALIMUMAB (PRE-FILLED PENS) 40 mg Inje',
#        'ADALIMUMAB!40mg/0.8mL!PRE-FILLED PEN',
#        'ADALIMUMAB 40mg/0.4ml PRE-FILLED PEN HUMIRA (HOMEC',
#        'ADALIMUMAB (AMGEVITA)  SYRINGE',
#        'ADALIMUMAB PFS HOMECARE (HUMIRA) 40 mg Subcutaneous Injection 1 Pre-Filled Syringe Pack',
#        'ADALIMUMAB (PRE-FILLED SYRINGE) 40 mg Injection',
#        'ADALIMUMAB 40mg/0.4mL PRE-FILLED SYRINGE',
#        'HOME Adalimumab Injection 40mg  -0.4ml PEN (Humira)       ',
#        'ADALIMUMAB IMRALDI 40 mg Injection Prefilled Syringe',
#        'Homecare Adalimumab Syringe (Amgevita) 40 Mg In 0.8Ml Injection',
#        'ADALIMUMAB (HUMIRA) 40 mg in 0.4mL Pre-filled Injection Pen',
#        'ADALIMUMAB HUMIRA 40 mg Injection Pre Filled Pen',
#        'HomeCare - ADALIMUMAB (HUMIRA) (PRE-FILLED PENS)',
#        'HC ADALIMUMAB 40 mg Injection Pre Filled Pen',
#        'ADALIMUMAB (HYRIMOZ ) (HOMECARE)',
#        'HOME ADALIMUMAB 40mg-0.8mL PF SYRINGE (AMGEVITA)',
#        'ADALIMUMAB (For HS) - HOMECARE 40 mg Preloaded Pen',
#        'ADALIMUMAB (HUMIRA) SYRINGE', 'ADALIMUMAB 40MG',
#        'ADALIMUMAB  PEN', 'ADALIMUMAB HUMIRA (HOMECARE)',
#        'Adalimumab - HUMIRA PEN 80MG/0.8ML    20013015',
#        'Adalimumab 40mg/0.4ml solution for injection pre-filled disposable devices',
#        'ADALIMUMAB (HUMIRA) (HOME DELIVERY) 40 mg Pre-filled Syringe',
#        'adalimumab (imraldi)$ pen',
#        'ADALIMUMAB (HUMIRA) 40 mg in 0.4mL Pre-filled Syringe',
#        'ADALIMUMAB (HUMIRA * HS * )',
#        'ADALIMUMAB 40mg/0.4mL PRE-FILLED PEN (2)',
#        'ADALIMUMAB!40mg/0.4mL!PRE-FILLED SYRINGE',
#        'ADALIMUMAB (AMGEVITA) (HOME DELIVERY) (G-S)',
#        'Variable HCD - Amgevita Adalimumab (CCG) - Risk Share',
#        'HomeCare - ADALIMUMAB (PRE-FILLED PENS) 40 mg Inj',
#        'HUMIRA (homecare syringe pack) ADALIMUMAB',
#        'HOMECARE - ADALIMUMAB (HUMIRA) PREFILLED SYRINGE 40 mg',
#        'ADALIMUMAB 40MG/0.8ML PF PEN (HYRIMOZ) (2) VIA HOMECARE',
#        'ADALIMUMAB (HYRIMOZ) (HOME DELIVERY)',
#        'HOME ADALIMUMAB 40mg  -0.8mL PF SYRINGE (AMGEVITA)',
#        'HomeCare - ADALIMUMAB (HUMIRA) (PRE-FILLED PENS) 4',
#        'Adalimumab Pen (Amgevita)', 'adalimumab $(humira) syr*HC*',
#        'Variable HCD - Amgevita Adalimumab (CCG)', 'ADALIMUMAB - IMRALDI',
#        'HomeCare - ADALIMUMAB (AMGEVITA) (HOMECARE) 20 mg',
#        'ADALIMUMAB (AMGEVITA) PENS (HOME DELIVERY ONLY)',
#        'HOMECARE - ADALIMUMAB 40 mg in 0.8ml Prefilled Syringe',
#        'ADALIMUMAB (Humira) 40 mg Injection',
#        'HomeCare - ADALIMUMAB (HUMIRA) (PRE-FILLED SYRINGE',
#        'HOME ADALIMUMAB 40mg  -0.8mL PF SYRINGE (AMGEVITA) ',
#        'ADALIMUMAB (Humira) [HOMECARE] (DERM H/S ONLY) (PEN) 40 mg Injection',
#        'Humira(Adalimumab)40MG PEN [2]',
#        'ADALIMUMAB 40 mg/0.4mL Soln for Inject PF Syringes',
#        'Homecare Adalimumab Syringe',
#        'HomeCare - ADALIMUMAB (HOMECARE) 20 mg Pre-Filled',
#        'HomeCare - ADALIMUMAB (Homecare) (HUMIRA) 20 mg Pr',
#        'ADALIMUMAB (DISCOUNTED)!40mg/0.4mL!PRE-FILLED PEN',
#        'Homecare Adalimumab Pen (Humira) 40 Mg In 0.4Ml Injection',
#        'HOMECARE ADALIMUMAB 40mg/0.4ml!PRE-FILLED PEN(2)(HS)',
#        'ADALIMUMAB PFS (AMGEVITA) 40 mg Subcutaneous Injection 2 Pre-Filled Syringe Pack',
#        'ADALIMUMAB **HOMECARE DELIVERY ONLY**',
#        'ADALIMUMAB 40mg/0.8mL!PRE-FILLED PEN (AMGEVITA)',
#        'ADALIMUMAB (IMRALDI) (HOME DELIVERY) 40 mg Pre-filled Syringe',
#        'ADALIMUMAB (HUMIRA) PRE-FILLED SYRINGE 40 mg Subcutaneous Injection',
#        'HOME - ADALIMUMAB 40mg/0.8mL PF PEN AMGEVITA0.8mL',
#        'HD_ADALIMUMAB 40mg/0.4mL PRE-FILLED PEN (2)',
#        'IMRALDI ADALIMUMAB', 'Homecare Adalimumab Syringe (Humira)',
#        'Homecare Adalimumab Syringe (Humira) 40 Mg In 0.4Ml Injection',
#        'HomeCare - ADALIMUMAB (HUMIRA) (HOMECARE) 20 mg Pr',
#        'ADALIMUMAB PEN 40 mg Injection',
#        'Adalimumab (Humira) (Pre-filled pen) (Homecare)',
#        'HC ADALIMUMAB (HYRIMOZ) 40MG PEN',
#        'ADALIMUMAB (IMRALDI) (PRE-FILLED PENS) 40 mg Injec',
#        'HOME Adalimumab Inj40mg/0.4ml PEN (Humira)',
#        'HOME Adalimumab Injection 40mg  -0.4ml PFS (Humira)',
#        'HOMECARE ADALIMUMAB PREFILLED DEVICE - (HYRIMOZ) 40 mg Injection',
#        'ADALIMUMAB (HUMIRA) (PRE-FILLED SYRINGE) 40 mg Inj',
#        'ADALIMUMAB 20mg/0.2mL PRE-FILLED SYRINGE',
#        'ADALIMUMAB 40MG/0.4ML SOLUTION FOR INJECTION PRE-FILLED SYRINGES',
#        'ADALIMUMAB REF PRICE',
#        'ADALIMUMAB   Amgevita 40mg 0.8mL PRE FILLEDSYRINGE',
#        'ADALIMUMAB (AMGEVITA)* ^',
#        'ADALIMUMAB (HUMIRA) 40 mg Pre-Filled Pen',
#        'ADALIMUMAB!40mg/0.8mL!PRE-FILLED PEN (HUMIRA)(HOMECARE)',
#        'HOME Adalimumab 40mg-0.4ml PEN (DERM - HS ONLY)',
#        'ADALIMUMAB!40mg/0.4mL!PRE-FILLED PEN (2)',
#        'ADALIMUMAB 40mg/0.8mL!PRE-FILLED PEN (IMRALDI)',
#        'ADALIMUMAB (HUMIRA) pre-filled syringe', 'ADALIMUMAB (HYRIMOZ )',
#        'HOMECARE ADALIMUMAB 40mg INJECTION (HUMIRA) (1)Gain Share',
#        'ADALIMUMAB (HUMIRA)_(HOMECARE) 20 mg in 0.2mL Pre-filled Syringe',
#        'Adalimumab (Hyrimoz)',
#        'Adalimumab Pen (Humira) 40 Mg In 0.4Ml Injection',
#        'ADALIMUMAB - IMRALDI (HOMECARE- HIDR. SUPP. INDICATION ONLY)',
#        'adalimumab $ pen *homecare*',
#        'HOMECARE ADALIMUMAB PREFILLED DEVICE - AS PRESCRIPTION 40 mg Injection',
#        'ADALIMUMAB   Amgevita 40mg 0.8mL PRE FILLED PEN  H',
#        'ADALIMUMAB (HYRIMOZ ) (REFERENCE PRICE)',
#        'ADALIMUMAB (IMRALDI) PRE-FILLED PEN',
#        '(HOME) HUMIRA (ADALIMUMAB)',
#        'HOMECARE ADALIMUMAB!40mg/0.8mL!PEN (HYRIMOZ) (HS)',
#        'ADALIMUMAB (HYRIMOZ ) (HOMECARE)REFERENCE PRICE',
#        'ADALIMUMAB (Pen) 40 mg Injection 2 x 40mg prefilled pen Pack',
#        'ADALIMUMAB (HUMIRA) (PRE-FILLED PENS) 40 mg Injec',
#        'ADALIMUMAB (HUMIRA) PRE-FILLED SYRINGE 40 mg Injection',
#        'ADALIMUMAB (Imraldi) [HOMECARE] (RHEUMATOLOGY) (PEN) 40 mg in 0.8ml Injection',
#        'HOMECARE ADALIMUMAB (HUMIRA) 40 mg Pre-filled syringe 2 x 40mg prefilled syringe Pack',
#        'Homecare Adalimumab Pen (Humira)',
#        'ADALIMUMAB (AMGEVITA) (PRE-FILLED PENS) 40 mg Inj',
#        'ADALIMUMAB (AMGEVITA)40mg/0.8mL PEN',
#        'ADALIMUMAB 40mg/0.4mL!PRE-FILLED SYRINGE (HUMIRA)',
#        'ADALIMUMAB!40mg/0.8mL!PRE-FILLED PEN (IMRALDI)',
#        'ADALIMUMAB (HUMIRA) - HOMECARE 40 mg Pen',
#        'ADALIMUMAB HOMECARE (HS INDICATION)', 'Adalimumab Pen (Humira)',
#        'ADALIMUMAB pre-filled syringe 40 mg Injection',
#        'HC - ADALIMUMAB (IMRALDI)',
#        'ADALIMUMAB 40mg/0.8mL PRE-FILLED PEN (AMGEVITA)(2)',
#        'ADALIMUMAB [HUMIRA] (HOMECARE) 40 mg Solution for Injection',
#        'Adalimumab (Humira) (Pre-filled pen)',
#        'ADALIMUMAB (HYRIMOZ) 40 mg Pre-Filled Pen',
#        'ADALIMUMAB (PRE-FILLED PENS) 40 mg Injection',
#        'HOME - ADALIMUMAB 40mg/0.8mL PF PEN(AMGEVITA)0.8mL',
#        'IMRALDI (ADALIMUMAB)', 'ADALIMUMAB PEN',
#        'adalimumab (HomeCare), injection,40mg/0.4ml, 1 Pre-filled pen',
#        'HomeCare - ADALIMUMAB (HUMIRA) (HOMECARE) 40 mg Pr',
#        'HC ADALIMUMAB 40 mg Injection Vial',
#        'HOMECARE - ADALIMUMAB (HUMIRA) 40 mg Injection',
#        'adalimumab (Humira)',
#        'ADALIMUMAB (AMGEVITA) (PRE-FILLED SYRINGE) 20 mg',
#        'ADALIMUMAB (Humira) 40 mg injection',
#        'HC - ADALIMUMAB (AMGEVITA)', 'HOMECARE ADALIMUMAB',
#        'Adalimumab (Imraldi Biosimilar)',
#        'ADALIMUMAB 40MG/0.4ML SOLUTION FOR INJECTION PRE-FILLED DISPOSABLE DEVICES 2 PRE-FILLED DISPOSABLE INJECTION',
#        "ADALIMUMAB PFS (FOR 'HS') ", 'ADALIMUMAB!40mg!PRELOADED PEN (1)',
#        'ADALIMUMAB (HUMIRA) (Pre-Filled Pen)',
#        'ADALIMUMAB (AMGEVITA) (PRE-FILLED SYRINGE) 40 mg',
#        'ADALIMUMAB   Amgevita 40mg 0.8mL PRE FILLED PEN',
#        'ADALIMUMAB (HYRIMOZ) PRE-FILLED SYRINGE 40 mg Subcutaneous Injection',
#        'ADALIMUMAB (HYRIMOZ ) (HOMECARE) REFERENCE PRICE',
#        "ADALIMUMAB (FOR 'HS') ",
#        'ADALIMUMAB (Humira FOR HOMECARE THERAPY)',
#        'ADALIMUMAB (PEN) (HUMIRA) (HHOME) 40 mg Injection Pen',
#        'ADALIMUMAB (pre-filled syringe)',
#        'ADALIMUMAB 40mg/0.4mL PEN (Humira) VIA HOMECARE (1)',
#        'ADALIMUMAB HYRIMOZ SYRINGE ()',
#        'ADALIMUMAB (HUMIRA) PRE-FILLED PEN 40 mg Subcutaneous Injection',
#        'ADALIMUMAB (HUMIRA) (Homecare) 40 mg Injection (Pre-filled syringe)',
#        'HOME Adalimumab INJ 40mg/0.4ml PFS (Humira)',
#        'ADALIMUMAB AMGEVITA (HOMECARE)',
#        'ADALIMUMAB - HOMECARE 40 mg Pen',
#        'Adalimumab Syringe (Amgevita) 40 Mg In 0.8Ml Injection',
#        'ADALIMUMAB!40mg/0.8mL!INJECTION (1 Vial)',
#        'ADALIMUMAB 20mg SYRINGE (HUMIRA)(HOMECARE)',
#        'ADALIMUMAB (HUMIRA) HOMECARE (HS INDICATION)',
#        'HOMECARE AMGEVITA (ADALIMUMAB) 40 mg Pre-filled syringe 2 x 40mg prefilled syringe Pack',
#        'Adalimumab (Hyrimoz) (Pre Filled Pen)',
#        'Adalimumab Syringe (Amgevita) 20 Mg In 0.4Ml Injection',
#        'HOMECARE ADALIMUMAB (HUMIRA) 20 mg syringe 2 Syringe Box',
#        'Homecare Adalimumab Syringe (Amgevita) 20 Mg In 0.4Ml Injection',
#        'ADALIMUMAB PFS HOMECARE (AMGEVITA) 40 mg Subcutaneous Injection 1 Pre-Filled Syringe Pack',
#        'ADALIMUMAB (AMGEVITA) **HOMECARE DELIVERY ONLY**',
#        'ADALIMUMAB [AMGEVITA] 20 mg/0.2mL Soln for Inject PF Syringes',
#        'HC - ADALIMUMAB (Amgevita)',
#        'ADALIMUMAB (HYRIMOZ ) REFERENCE COST CHARGE',
#        'Adalimumab Syringe (Homecare)',
#        'ADALIMUMAB (Humira) (Pre-filled Pen)',
#        'ADALIMUMAB (Homecare) (for HS)',
#        'ADALIMUMAB á(IMRALDI) **HOMECARE DELIVERY ONLY**',
#        'adalimumab HS (humira)$pen*HC*',
#        'ADALIMUMAB (D2E7) 40 mg Subcutaneous Injection',
#        'HOMECARE ADALIMUMAB!40mg/0.8mL!PFS (AMGEVITA)',
#        'HC ADALIMUMAB HYRIMOZ 40 mg Injection Pre Filled Pen',
#        'Adalimumab Syringe (Amgevita)',
#        'HC ADALIMUMAB (AMGEVITA) 40MG/0.8ML PREFILLED SYRINGE',
#        'ADALIMUMAB (IMRALDI) 40 mg in 0.8mL Pre-Filled Pen',
#        'ADALIMUMAB [IMRALDI] 40 mg/0.8mL Soln for Inject PF Disp Device',
#        'ADALIMUMAB!20mg/0.2mL!PRE-FILLED SYRINGE'], dtype=object)

# %% [markdown]
# **Top 20 drug names**
#
# The table below summaries the 20 unique drug names that appear the most in the dataset.

# %%
drug_name_summary["NumberOfAppearances - no NULLS"] = drug_name_summary.fillna(0)["NumberOfAppearances"]

drug_name_summary_top20 = drug_name_summary.groupby('DrugName', dropna = False).agg({"NumberOfAppearances - no NULLS": "sum"})
drug_name_summary_top20 = drug_name_summary_top20.sort_values(by = "NumberOfAppearances - no NULLS", ascending = False)
drug_name_summary_top20.head(20)
# Out:
#                        NumberOfAppearances - no NULLS
# DrugName
# FLUOROURACIL                                 154970.0
# CAPECITABINE                                  98188.0
# FILGRASTIM                                    97544.0
# CYCLOPHOSPHAMIDE                              97044.0
# TACROLIMUS                                    82349.0
# NaN                                           82302.0
# CARBOPLATIN                                   80951.0
# PACLITAXEL                                    75804.0
# DEXAMETHASONE                                 55976.0
# OXALIPLATIN                                   55448.0
# MYCOPHENOLATE MOFETIL                         54842.0
# BORTEZOMIB                                    54378.0
# EPIRUBICIN                                    53962.0
# DOCETAXEL                                     53679.0
# DIMETHYL FUMARATE                             49720.0
# EPOETIN ALFA                                  49214.0
# METHOTREXATE                                  48206.0
# Aranesp                                       48009.0
# GEMCITABINE                                   45064.0
# IRINOTECAN                                    42527.0
